# %%
import os, pathlib
cache_dir = pathlib.Path(".mplcache").resolve()
cache_dir.mkdir(parents=True, exist_ok=True)
os.environ["MPLCONFIGDIR"] = "/Users/corra/Desktop/old macbook/Desktop/Data_Science_KM/DataScience/Capstone 2/.mplconfig"
os.environ["MPL_SKIP_MACOS_FONTS"] = "1"

# %%
# Import Libraries
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Optional: Configure matplotlib for inline display in Jupyter
# %matplotlib inline

# %%
#Loading the Data

df = pd.read_csv('brfss_2022_final.csv')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    DRNK3GE5  SLEPTIM1  EMTSUPRT  INCOME3  SEXVAR
# 0       NaN       8.0       1.0     99.0       2
# 1       NaN       6.0       1.0      5.0       2
# 2       NaN       5.0       2.0     10.0       2
# 3       NaN       7.0       1.0     77.0       2
# 4      88.0       9.0       1.0      5.0       2

# %%
# Understanding structure of the Data

# %%
#Shape of the data to tell us # of rows and columns

print(df.shape)
# Out:
# (445132, 5)

# %%
#Display column data types

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DRNK3GE5  209849 non-null  float64
#  1   SLEPTIM1  445129 non-null  float64
#  2   EMTSUPRT  254141 non-null  float64
#  3   INCOME3   432200 non-null  float64
#  4   SEXVAR    445132 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 17.0 MB
# None

# %%
#Summarize numerical columns
print(df.describe())
# Out:
#             DRNK3GE5       SLEPTIM1       EMTSUPRT        INCOME3  \
# count  209849.000000  445129.000000  254141.000000  432200.000000
# mean       65.323223       7.912277       1.958027      22.723947
# std        37.089638       8.164575       1.280953      32.977432
# min         1.000000       1.000000       1.000000       1.000000
# 25%        15.000000       6.000000       1.000000       6.000000
# 50%        88.000000       7.000000       2.000000       8.000000
# 75%        88.000000       8.000000       2.000000      10.000000
# max        99.000000      99.000000       9.000000      99.000000
#
#               SEXVAR
# count  445132.000000
# mean        1.529939
# std         0.499103
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         2.000000

# %%
# Identifying missing data

# %%
#Visualize missing data

print(df.isna().sum())
# Out:
# DRNK3GE5    235283
# SLEPTIM1         3
# EMTSUPRT    190991
# INCOME3      12932
# SEXVAR           0
# dtype: int64

# %%
# Check for missing values

missing_data = df.isnull()
print(missing_data)
# Out:
#         DRNK3GE5  SLEPTIM1  EMTSUPRT  INCOME3  SEXVAR
# 0           True     False     False    False   False
# 1           True     False     False    False   False
# 2           True     False     False    False   False
# 3           True     False     False    False   False
# 4          False     False     False    False   False
# ...          ...       ...       ...      ...     ...
# 445127      True     False     False    False   False
# 445128      True     False     False    False   False
# 445129      True     False     False    False   False
# 445130      True     False     False    False   False
# 445131     False     False     False    False   False
#
# [445132 rows x 5 columns]

# %%
#At this point, there's a lot of missing data but also a lot of data
# researchers used 99, 88, and 77 to indicate missing values
#first step to handle missing data is to replace 99,88,77 with nan
df = df.replace(99, np.nan)
df = df.replace(88, np.nan)
df = df.replace(77, np.nan)
print(df.head(25))
# Out:
#     DRNK3GE5  SLEPTIM1  EMTSUPRT  INCOME3  SEXVAR
# 0        NaN       8.0       1.0      NaN       2
# 1        NaN       6.0       1.0      5.0       2
# 2        NaN       5.0       2.0     10.0       2
# 3        NaN       7.0       1.0      NaN       2
# 4        NaN       9.0       1.0      5.0       2
# 5        NaN       7.0       2.0      NaN       1
# 6        NaN       7.0       1.0      8.0       2
# 7        NaN       8.0       1.0      7.0       2
# 8        NaN       6.0       1.0      7.0       2
# 9        NaN       7.0       1.0      7.0       2
# 10       NaN       8.0       1.0      5.0       2
# 11       NaN       6.0       1.0      NaN       2
# 12       NaN       6.0       1.0      7.0       1
# 13       NaN       8.0       1.0      9.0       1
# 14       NaN       8.0       2.0      5.0       2
# 15       NaN       8.0       1.0      7.0       2
# 16       NaN       6.0       1.0      NaN       2
# 17       NaN       6.0       1.0      6.0       2
# 18       NaN       4.0       1.0      5.0       2
# 19       NaN       6.0       NaN      NaN       2
# 20       NaN       6.0       2.0      8.0       2
# 21       NaN       9.0       2.0      9.0       1
# 22       NaN       7.0       NaN      4.0       2
# 23       NaN       8.0       1.0      NaN       2
# 24       NaN       8.0       1.0      NaN       1

# %%
#decided to drop all rows with any missing data
df_nomissing = df.dropna()
print(df_nomissing.head())
# Out:
#      DRNK3GE5  SLEPTIM1  EMTSUPRT  INCOME3  SEXVAR
# 31        4.0       4.0       1.0      8.0       1
# 69        1.0       8.0       3.0      6.0       1
# 150       1.0       8.0       1.0      8.0       1
# 160       1.0       3.0       2.0      7.0       1
# 239       2.0       6.0       2.0      2.0       2

# %%
#looking at the shape of data again
print(df_nomissing.shape)
# Out:
# (30142, 5)

# %%
#running how much missing data there is now
print(df_nomissing.isna().sum())
# Out:
# DRNK3GE5    0
# SLEPTIM1    0
# EMTSUPRT    0
# INCOME3     0
# SEXVAR      0
# dtype: int64

# %%
#running descriptives again on cleaned data
print(df_nomissing.describe())
# Out:
#            DRNK3GE5      SLEPTIM1      EMTSUPRT       INCOME3        SEXVAR
# count  30142.000000  30142.000000  30142.000000  30142.000000  30142.000000
# mean       4.860925      6.924756      1.971999      7.414870      1.392509
# std        6.801457      1.382796      1.143735      2.390005      0.488317
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      6.000000      1.000000      6.000000      1.000000
# 50%        2.000000      7.000000      2.000000      8.000000      1.000000
# 75%        5.000000      8.000000      2.000000      9.000000      2.000000
# max       76.000000     24.000000      9.000000     11.000000      2.000000

# %%
# Univariate analysis for numerical data
# examines each single var to describe & summarize its distribution, central tendency, and variability

# %%
# Variable name:
df_nomissing['DRNK3GE5'].hist(bins=20)
plt.title('Distribution of Binge Drinking')
plt.show()

# %%
# Variable name:
# wanted to split the bins into 2 hr intervals to see the spread of data better
# implemented a range parameter
df['SLEPTIM1'].hist(bins=12, range=(0, 24))
plt.title('Distribution of Sleep Time')
plt.xlabel('Hours of Sleep')
plt.ylabel('Frequency')
plt.show()

# %%
# Variable name:
df['EMTSUPRT'].hist(bins=20)
plt.title('Distribution of Emotional Support')
plt.show()

# %%
# Univariate analysis for categorical data
# examines each single var to describe & summarize its distribution, central tendency, and variability

# %%
# Bar Plot
#sns.countplot(x='INCOME3', data=df)

sns.countplot(data=df, x='INCOME3', palette='deep')
plt.title('Income Distribution')
plt.xlabel('Income Range')
plt.ylabel('Frequency')
plt.show()
# Out:
# /var/folders/k9/14wtpz7n6dz958nl7hkt64lw0000gn/T/ipykernel_14006/2795297698.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='INCOME3', palette='deep')

# %%
#Distribution of Sex

#needed to map the values to female = 0, male = 1
# Map the values to 'Male' and 'Female'
df['Sex_Label'] = df['SEXVAR'].map({1: 'Female', 2: 'Male'})

sns.countplot(data=df, x='Sex_Label', palette='deep')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.show()
# Out:
# /var/folders/k9/14wtpz7n6dz958nl7hkt64lw0000gn/T/ipykernel_14006/3513350114.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Sex_Label', palette='deep')
